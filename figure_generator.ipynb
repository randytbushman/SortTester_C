# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
from cycler import cycler
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False

# %%
def show_graph(output_file):
    
    plt.legend()
    plt.ticklabel_format(style='plain')
    plt.title("Sorting Algorithm Time Comparison")
    plt.xlabel("Array Length")
    plt.ylabel("Time (ms)")
    plt.grid()
    plt.rcParams['savefig.dpi'] = 600
    mpl.rcParams['axes.spines.top'] = False
    mpl.rcParams['axes.spines.right'] = False
    plt.tight_layout()
    plt.savefig(output_file)
    plt.show()
    
    
def parse_csv(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
        headers = lines[0].strip().split(",")
        sort_col_list = [[] for _ in range(len(headers))]

        for row in range(1, len(lines)):
            line = lines[row].strip().split(",")
            for col in range(len(line)):
                sort_col_list[col].append(float(line[col]))

        return sort_col_list[0], sort_col_list, headers

# %%
x_arr, sort_col_list, headers = parse_csv("figure_5.csv")
     
markers = ['v', 's', 'h', 'D', 'X']
for i in range(1, len(headers)):
    plt.plot(x_arr[::30], sort_col_list[i][::30], markers[i-1] + "-", label=headers[i])

show_graph("figure_5.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x_arr, sort_col_list, headers = parse_csv("figure_6.csv")
     
markers = ['v', 's', "h", 'D', 'X']
for i in range(1, len(headers)):
    plt.plot(x_arr[::30], sort_col_list[i][::30], markers[i-1] + "-", label=headers[i])

show_graph("figure_6.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x_arr, sort_col_list, headers = parse_csv("figure_7.csv")
     
markers = ['v', 's']
for i in range(1, len(headers)):
    plt.plot(x_arr[::100], sort_col_list[i][::100], markers[i-1] + "-", label=headers[i])

show_graph("figure_7.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x_arr, sort_col_list, headers = parse_csv("figure_8.csv")
     
markers = ['v', 's']
for i in range(1, len(headers)):
    plt.plot(x_arr[::29], sort_col_list[i][::29], markers[i-1] + "-", label=headers[i])

show_graph("figure_8.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x_arr, sort_col_list, headers = parse_csv("figure_9.csv")
     
markers = ['v', 's', "h", 'D']
for i in range(1, len(headers)):
    plt.plot(x_arr[::30], sort_col_list[i][::30], markers[i-1] + "-", label=headers[i])

show_graph("figure_9.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x_arr, sort_col_list, headers = parse_csv("figure_10.csv")
     
markers = ['v', 's', "h", 'D']
for i in range(1, len(headers)):
    plt.plot(x_arr[::30], sort_col_list[i][::30], markers[i-1] + "-", label=headers[i])

show_graph("figure_10.png")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
